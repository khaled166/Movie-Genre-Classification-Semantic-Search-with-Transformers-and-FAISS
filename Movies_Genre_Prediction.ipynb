# %% [markdown]
# <center>
#     <h2 style="color:white;">🎯 Project Overview: Movie Genre Prediction</h2>
#     <img src="download.jpg" alt="Churn Image" width="600"/>
# </center>

# %% [markdown]
# <center><span style="font-size:30px; color:white; font-weight:bold;">Description</span></center>
#
# #### This dataset contains detailed **plot summaries of 34,886 movies** collected from Wikipedia, covering a wide range of films across different countries, languages, and eras. It includes both metadata and narrative content for each film, making it suitable for tasks such as genre classification, recommendation systems, natural language processing (NLP), and retrieval-augmented generation (RAG).
#
# #### 📌 **Key Columns:**
# - **Title** – Movie name.
# - **Release Year** – Year the movie was released.
# - **Origin/Ethnicity** – Country or cultural origin of the movie.
# - **Director** – Name of the movie's director(s).
# - **Cast** – Key actors/actresses involved in the movie.
# - **Genre** – Multi-label target column specifying the genre(s) (e.g., drama, action, horror).
# - **Plot** – The full narrative description or synopsis of the movie.
# - **Wiki Page** – URL to the original Wikipedia source.

# %% [markdown]
# <center><span style="font-size:30px; color:white; font-weight:bold;">List of Packages and Modules</span></center>
#
# #### 🧰 The following Python libraries and modules were used throughout this project for data cleaning, feature engineering, modeling, evaluation, and deployment:
#
# ---
#
# ### 📊 **Exploratory Data Analysis (EDA) & Visualization**
# - `pandas` – Data manipulation and analysis
# - `numpy` – Numerical operations
# - `matplotlib.pyplot` – Static data visualizations (e.g., histograms, scatter plots)
# - `seaborn` – Statistical plots and heatmaps
# - `plotly.express` – Interactive and animated charts
# - `wordcloud` – Generate word clouds from cast, plot, or genre text data
#
# ---
#
# ### 🧹 **Preprocessing & Feature Engineering**
# - `re`, `ast`, `json` – Text cleaning, safe parsing of stringified lists or JSON
# - `sklearn.preprocessing` – Label encoding, scaling (`RobustScaler`, `StandardScaler`, `MinMaxScaler`, `MultiLabelBinarizer`)
# - `sklearn.feature_extraction.text` – `TfidfVectorizer` for converting plots into TF-IDF features
# - `category_encoders` – Advanced encoders like `BinaryEncoder` and `OrdinalEncoder`
# - `sklearn.compose` – `ColumnTransformer` for applying transformations to specific column groups
# - `collections.defaultdict` – Grouping and frequency calculations for custom logic
#
# ---
#
# ### 🤖 **Modeling & Evaluation**
# - `sklearn.linear_model`, `tree`, `ensemble`, `neural_network`, `svm` – Machine learning models (e.g., Logistic Regression, Decision Trees, Random Forest, Gradient Boosting, MLPClassifier, SVM)
# - `xgboost`, `lightgbm` – High-performance gradient boosting models
# - `sklearn.multiclass` – `OneVsRestClassifier` for multi-label classification
# - `sklearn.pipeline` & `imblearn.pipeline` – Pipelines for clean modeling workflows with preprocessing and balancing
# - `imbalanced-learn` – Oversampling techniques such as `SMOTE`, `RandomOverSampler`
# - `sklearn.model_selection` – `train_test_split`, `cross_validate`, `GridSearchCV`, `RandomizedSearchCV`
# - `sklearn.metrics` – `accuracy_score`, `classification_report`, `hamming_loss`, `make_scorer`
#
# ---
#
# ### 🔍 **Vector Search & RAG (Retrieval-Augmented Generation)**
# - `sentence-transformers` – Generate sentence-level embeddings for semantic understanding
# - `faiss` – Build and search high-performance vector similarity indices
# - `transformers` – Hugging Face pipeline for using models like `facebook/bart-large-cnn` for summarization
# - `evaluate` – Evaluate generated text using `ROUGE` and other NLP metrics
#
# ---
#
# ### 🛠️ **Utilities & Config**
# - `os`, `warnings`, `time.perf_counter` – System interactions, performance tracking, and warning suppression
# - `IPython.display.Markdown` – Display markdown text inside notebooks

# %%
# 📦 General Purpose Utilities
import os                              # For interacting with file systems
import re                              # For regular expressions (e.g., text cleaning)
import json                            # Parsing and manipulating JSON data
import ast                             # Safe evaluation of Python literals (e.g., stringified lists)
import warnings                        # Suppress warning messages during execution
from time import perf_counter          # To measure execution time of operations
from collections import defaultdict    # For grouping or counting with default values
warnings.filterwarnings("ignore")      # Ignore all warning messages during execution

# 📊 Data Manipulation and Analysis
import pandas as pd                    # Primary library for handling tabular data
import numpy as np                     # Numerical operations on arrays and matrices

# 📈 Data Visualization
import matplotlib.pyplot as plt        # Static plotting (histograms, bar charts, etc.)
import seaborn as sns                  # Advanced statistical plots (e.g., heatmaps, violin plots)
import plotly.express as px            # Interactive and animated visualizations
from wordcloud import WordCloud        # Visualize text frequency as word clouds

# 🧠 Machine Learning Models
from sklearn.linear_model import LogisticRegression           # Linear model for classification
from sklearn.tree import DecisionTreeClassifier               # Decision tree classifier
from sklearn.ensemble import RandomForestClassifier           # Ensemble model with multiple trees
from sklearn.ensemble import GradientBoostingClassifier       # Boosted trees for higher accuracy
from sklearn.neighbors import KNeighborsClassifier            # K-NN based classifier
from sklearn.neural_network import MLPClassifier              # Neural network-based classifier
from sklearn.svm import SVC , LinearSVC                                 # Support Vector Classifier
from xgboost import XGBClassifier                             # Extreme Gradient Boosting model
from lightgbm import LGBMClassifier                           # Fast gradient boosting by LightGBM

# ⚙️ Feature Engineering and Preprocessing
from sklearn.preprocessing import (
    OneHotEncoder, LabelEncoder, RobustScaler,
    StandardScaler, MinMaxScaler, MultiLabelBinarizer
)                                                             # Encoding & scaling features
from sklearn.feature_extraction.text import TfidfVectorizer   # Convert text to TF-IDF features
from category_encoders import BinaryEncoder, OrdinalEncoder   # For encoding categorical variables
from sklearn.compose import ColumnTransformer                 # Apply preprocessing to specific columns

# 🧪 Pipelines
from sklearn.pipeline import Pipeline                         # Pipeline for clean ML workflow
from imblearn.pipeline import Pipeline as ImbPipeline         # Pipeline with imbalanced data support
from sklearn.impute import SimpleImputer                      # Handle missing values in datasets

# ⚖️ Handling Imbalanced Datasets
from imblearn.over_sampling import SMOTE, RandomOverSampler   # Synthetic oversampling to balance labels

# 🔍 Model Evaluation and Hyperparameter Tuning
from sklearn.model_selection import (
    train_test_split, cross_validate,
    GridSearchCV, RandomizedSearchCV
)                                                             # Data splitting and tuning
from sklearn.metrics import (
    accuracy_score, classification_report,
    make_scorer, hamming_loss
)                                                             # Model performance metrics

# 🧠 Multilabel and Meta Strategies
from sklearn.multiclass import OneVsRestClassifier            # For handling multilabel classification

# 📄 Jupyter Notebook Utilities
from IPython.display import Markdown as md                    # Render styled markdown in notebooks

# 🤗 NLP & Transformers
from transformers import (
    pipeline, AutoModelForSeq2SeqLM, AutoTokenizer
)                                                             # For text summarization and LLMs

# 🧠 NLP Embeddings and Vector Search
import faiss                                                  # Facebook's vector search library
from sentence_transformers import SentenceTransformer         # Sentence-level embeddings

# 📏 Evaluation Metrics
import evaluate                                                # Hugging Face metrics (e.g., ROUGE, BLEU)

# 🛠️ Parallel Processing and Progress Bars
from tqdm import tqdm # Progress bar for loops and operations
from pandarallel import pandarallel # Initialize pandarallel
pandarallel.initialize(progress_bar=True) # Initialize pandarallel for parallel processing
import swifter # Parallel processing for pandas
# Out:
# INFO: Pandarallel will run on 10 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/

# %% [markdown]
# <p align="center">
#   <span style="font-size:30px; color:white; font-weight:bold;">Data Collection</span>
# </p>
#
# <p style="color:white; font-size:16px; text-align:justify;">
# The dataset was compiled from multiple sources, including Wikipedia and TMDB, combining plot summaries, metadata, and cast information into a unified structure to support further analysis and modeling.
# </p>

# %%
MainData = pd.read_csv("wiki_movie_plots_deduped.csv") # Load the dataset into a DataFrame
auxiliary_TMDB_Movies = pd.read_csv("tmdb_5000_movies.csv") # Load auxiliary dataset for TMDB movies
auxiliary_TMDB_Credits = pd.read_csv("tmdb_5000_credits.csv") # Load auxiliary dataset for TMDB credits

# %%
print("MainData:")
display(MainData.head(3)) # Display the first 3 rows of the main dataset
print("auxiliary_TMDB_Movies:")
display(auxiliary_TMDB_Movies.head(3)) # Display the first 3 rows of the auxiliary TMDB movies dataset
print("auxiliary_TMDB_Credits:")
display(auxiliary_TMDB_Credits.head(3)) # Display the first 3 rows of the auxiliary TMDB credits dataset
# Out:
# MainData:
#   Release Year                          Title Origin/Ethnicity Director Cast  \
# 0         1901         Kansas Saloon Smashers         American  Unknown  NaN
# 1         1901  Love by the Light of the Moon         American  Unknown  NaN
# 2         1901        The Martyred Presidents         American  Unknown  NaN
#
#      Genre                                          Wiki Page  \
# 0  unknown  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  unknown  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  unknown  https://en.wikipedia.org/wiki/The_Martyred_Pre...
#
#                                                 Plot Unnamed: 8
# 0  A bartender is working at a saloon, serving dr...        NaN
# 1  The moon, painted with a smiling face hangs ov...        NaN
# 2  The film, just over a minute long, is composed...        NaN
# auxiliary_TMDB_Movies:
#       budget                                             genres  \
# ...

# %%
print("MainData............................\n")  # Display information about the main dataset
MainData.info()  # Display information about the main dataset
print("\nauxiliary_TMDB_Movies................\n")  # Display information about the auxiliary TMDB movies dataset
auxiliary_TMDB_Movies.info()  # Display information about the auxiliary TMDB movies dataset
print("\nauxiliary_TMDB_Credits...............\n")  # Display information about the auxiliary TMDB credits
auxiliary_TMDB_Credits.info()  # Display information about the auxiliary TMDB credits
# Out:
# MainData............................
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34892 entries, 0 to 34891
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Release Year      34892 non-null  object
#  1   Title             34890 non-null  object
#  2   Origin/Ethnicity  34890 non-null  object
#  3   Director          34890 non-null  object
#  4   Cast              33468 non-null  object
#  5   Genre             34890 non-null  object
#  6   Wiki Page         34890 non-null  object
#  7   Plot              34890 non-null  object
#  8   Unnamed: 8        2 non-null      object
# dtypes: object(9)
# memory usage: 2.4+ MB
#
# auxiliary_TMDB_Movies................
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
# ...

# %%
print("MainData Description")  # Display descriptive statistics of the main dataset
display(MainData.describe())  # Display descriptive statistics of the main dataset
print("\nauxiliary_TMDB_Movies Description ")  # Display descriptive statistics of the auxiliary TMDB movies datase
display(auxiliary_TMDB_Movies.describe())  # Display descriptive statistics of the auxiliary TMDB movies dataset
print("\nauxiliary_TMDB_Credits Description")  # Display descriptive statistics of the auxiliary TMDB credits dataset  
auxiliary_TMDB_Credits.describe()  # Display descriptive statistics of the auxiliary TMDB credits dataset
# Out:
# MainData Description
#        Release Year                 Title Origin/Ethnicity Director  \
# count         34892                 34890            34890    34890
# unique          120                 32434               26    12595
# top            2013  The Three Musketeers         American  Unknown
# freq           1021                     8            17377     1124
#
#                  Cast    Genre  \
# count           33468    34890
# unique          32184     2267
# top     Tom and Jerry  unknown
# freq               80     6083
#
#                                                 Wiki Page  \
# count                                               34890
# unique                                              34072
# top     https://en.wikipedia.org/wiki/Himitsu_Sentai_G...
# freq                                                    5
#
#                                                      Plot  \
# count                                               34890
# ...

# %%
display(MainData.shape)  # Get the shape of the main dataset (rows, columns)
display(auxiliary_TMDB_Movies.shape)  # Get the shape of the auxiliary TMDB movies dataset (rows, columns)
auxiliary_TMDB_Credits.shape  # Get the shape of the auxiliary TMDB credits
# Out:
# (34892, 9)
# (4803, 20)
# (4813, 1265)

# %%
def clean_unnamed_columns(df):
    """
    Removes unnamed columns (like 'Unnamed: 0', 'Unnamed: 8') from a DataFrame.
    Args:
        df (pd.DataFrame): Input DataFrame.
    Returns:
        pd.DataFrame: Cleaned DataFrame without unnamed columns.
    """
    return df.loc[:, ~df.columns.str.contains("^Unnamed")]



# Clean the DataFrames by removing unnamed columns
MainData = clean_unnamed_columns(MainData) 
auxiliary_TMDB_Movies = clean_unnamed_columns(auxiliary_TMDB_Movies)
auxiliary_TMDB_Credits = clean_unnamed_columns(auxiliary_TMDB_Credits)

# %%
def extract_names_from_json(text):
    try:
        items = json.loads(text) if isinstance(text, str) else text
        return ", ".join([d['name'] for d in items if 'name' in d])
    except Exception:
        return None

# %%
auxiliary_TMDB_Credits['cast'] = auxiliary_TMDB_Credits['cast'].swifter.apply(extract_names_from_json)
auxiliary_TMDB_Credits['crew'] = auxiliary_TMDB_Credits['crew'].swifter.apply(extract_names_from_json)
auxiliary_TMDB_Movies['genres'] = auxiliary_TMDB_Movies['genres'].swifter.apply(extract_names_from_json)
# Out:
# ...
# Pandas Apply:   0%|          | 0/4803 [00:00<?, ?it/s]

# %%
auxiliary_TMDB_Credits.head(3)  # Display the first 3 rows of the expanded auxiliary TMDB movies dataset
# Out:
#   movie_id                                     title  \
# 0    19995                                    Avatar
# 1      285  Pirates of the Caribbean: At World's End
# 2   206647                                   Spectre
#
#                                                 cast  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1  Johnny Depp, Orlando Bloom, Keira Knightley, S...
# 2  Daniel Craig, Christoph Waltz, Léa Seydoux, Ra...
#
#                                                 crew
# 0  Stephen E. Rivkin, Rick Carter, Christopher Bo...
# 1  Dariusz Wolski, Gore Verbinski, Jerry Bruckhei...
# 2  Thomas Newman, Sam Mendes, Anna Pinnock, John ...

# %%
auxiliary_TMDB_Movies.head(3)  # Display the first 3 rows of the expanded auxiliary TMDB movies dataset
# Out:
#       budget                                       genres  \
# 0  237000000  Action, Adventure, Fantasy, Science Fiction
# 1  300000000                   Adventure, Fantasy, Action
# 2  245000000                     Action, Adventure, Crime
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
df = (
    MainData # Start with the main dataset
    .merge(auxiliary_TMDB_Movies, how='left', left_on='Title', right_on='title')  # Merge with auxiliary TMDB movies on 'Title' and 'title'
    .merge(auxiliary_TMDB_Credits, how='left', on='title') # Merge with auxiliary TMDB credits on 'title'
)

# %%
df.shape  # Display the first 3 rows of the merged DataFrame
# Out:
# (34907, 31)

# %% [markdown]
# <center><span style="font-size:30px; color:white; font-weight:bold;">EDA (Exploratory Data Analysis) & Preprocessing</span></center>
#
# ## 📊 Uni-Variate, Bi-Variate, and Multi-Variate Analysis
#
# This section explores the distribution and relationships between variables in the dataset to uncover meaningful insights and guide feature engineering.
#
# ---
#
# ### 🧹 Preprocessing Techniques Used:
#
# 1. **Handling Missing Values**
#    - Removed or imputed rows with missing data in key fields (e.g., 'Release Year', 'Cast').
#    - Coerced non-numeric year entries and converted to integers after filtering.
#
# 2. **Data Cleaning**
#    - Removed redundant text like `"Director:"`, `"Cast:"` from text fields using regex.
#    - Cleaned and standardized text in columns like `'Title'`, `'Plot'`, `'Director'`, `'Cast'` by:
#      - Removing punctuation & special characters.
#      - Lowercasing all text.
#      - Stripping extra whitespace.
#
# 3. **Duplicate Removal**
#    - Checked and removed duplicate rows based on `'Title'`, `'Plot'`, etc., where necessary.
#
# 4. **Outlier Detection**
#    - Identified outliers in categorical fields using value counts and thresholds (e.g., genres appearing < 20 times).
#    - Considered rare genres for merging into an `'Other'` class.
#
# 5. **Feature Engineering**
#    - Extracted a new `'Decade'` column from `'Release Year'`.
# ---
#
# > These steps ensure high-quality, structured, and informative data that can enhance model performance and provide meaningful business insights.

# %%
df.info()  # Display information about the merged DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34907 entries, 0 to 34906
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Release Year          34907 non-null  object
#  1   Title                 34905 non-null  object
#  2   Origin/Ethnicity      34905 non-null  object
#  3   Director              34905 non-null  object
#  4   Cast                  33483 non-null  object
#  5   Genre                 34905 non-null  object
#  6   Wiki Page             34905 non-null  object
#  7   Plot                  34905 non-null  object
#  8   budget                4105 non-null   float64
#  9   genres                4105 non-null   object
#  10  homepage              1472 non-null   object
#  11  id                    4105 non-null   float64
#  12  keywords              4105 non-null   object
#  13  original_language     4105 non-null   object
#  14  original_title        4105 non-null   object
# ...

# %%
df.describe()  # Display descriptive statistics of the merged DataFrame
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.105000e+03    4105.000000  4105.000000  4.105000e+03  4105.000000
# mean   3.551309e+07   44155.831425    26.136917  1.040461e+08   109.977832
# std    4.411732e+07   73220.181158    36.443716  1.841609e+08    21.401475
# min    0.000000e+00       5.000000     0.001117  0.000000e+00     0.000000
# 25%    5.000000e+06    7509.000000     7.701186  3.000000e+06    96.000000
# 50%    2.000000e+07   11968.000000    17.457947  3.689372e+07   106.000000
# 75%    5.000000e+07   43933.000000    33.747825  1.197234e+08   120.000000
# max    3.800000e+08  426469.000000   875.581305  2.787965e+09   276.000000
#
#        vote_average    vote_count
# count   4105.000000   4105.000000
# mean       6.251035    844.344702
# std        0.888298   1355.402276
# min        0.000000      0.000000
# 25%        5.700000    109.000000
# 50%        6.300000    356.000000
# 75%        6.800000    959.000000
# ...

# %%
df.duplicated().sum()  # Check for duplicate rows in the DataFrame
# Out:
# 3

# %%
df.drop_duplicates(inplace=True)  # Remove duplicate rows from the DataFrame

# %% [markdown]
# 1. **Handling Missing Values**  & **Data Cleaning**

# %%
# Count missing values in each column of the DataFrame as a percentage
px.bar(x=df.columns, y=df.isna().mean() * 100, labels={'x': 'Feature', 'y': 'Missing (%)'}, title='Missing Values (%)')

# %%
def impute_value(main_val, aux_val):
    if pd.isna(main_val) or str(main_val).strip().lower() in ["", "unknown", "nan"]:
        return aux_val
    return main_val

# %%
# Define what counts as "missing" or "invalid"
def is_missing(val):
    return pd.isna(val) or str(val).strip().lower() in ["", "unknown", "nan"]

# %%
before_missing = {
    'Cast': df['Cast'].apply(is_missing).sum(),
    'Director': df['Director'].apply(is_missing).sum(),
    'Genre': df['Genre'].apply(is_missing).sum()
}

# %%
# Apply imputations
df['Cast'] = df.swifter.apply(lambda row: impute_value(row['Cast'], row['cast']), axis=1)
df['Director'] = df.swifter.apply(lambda row: impute_value(row['Director'], row['crew']), axis=1)
df['Genre'] = df.swifter.apply(lambda row: impute_value(row['Genre'], row['genres']), axis=1)
# Out:
# ...
# Pandas Apply:   0%|          | 0/34904 [00:00<?, ?it/s]

# %%
after_missing = {
    'Cast': df['Cast'].apply(is_missing).sum(),
    'Director': df['Director'].apply(is_missing).sum(),
    'Genre': df['Genre'].apply(is_missing).sum()
}

# %%
imputed_counts = {
    col: before_missing[col] - after_missing[col] # Count of rows imputed for each column
    for col in before_missing # Iterate over the columns with missing values
}


# Display the number of rows imputed for each column
print("Imputed Rows per Column:\n______________________________\n")
for col, count in imputed_counts.items():
    print(f"{col}: {count} rows updated")
# Out:
# Imputed Rows per Column:
# ______________________________
#
# Cast: 38 rows updated
# Director: 22 rows updated
# Genre: 226 rows updated

# %%
# Keep only rows where 'Release Year' is a valid number (e.g., 1901, 2020)
df = df[pd.to_numeric(df['Release Year'], errors='coerce').notna()]

# Convert to integer type (nullable Int64 to support missing values safely)
df['Release Year'] = df['Release Year'].astype('int')

# %%
# Set threshold (e.g., 20%)
threshold = 0.2

# Calculate percentage of missing values per column
missing_ratio = df.isna().mean()

# Identify columns to drop
cols_to_drop = missing_ratio[missing_ratio > threshold].index

# Drop them from the DataFrame
df.drop(columns=cols_to_drop, inplace=True)

# Print what was dropped
print(f"Dropped {len(cols_to_drop)} columns with >{int(threshold*100)}% missing values:")
print(list(cols_to_drop))
# Out:
# Dropped 23 columns with >20% missing values:
# ['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count', 'movie_id', 'cast', 'crew']

# %%
import re

# Clean text function (unchanged)
def clean_text(text):
    text = re.sub(r"\'", "", str(text))       # Ensure text is string
    text = re.sub(r"[^a-zA-Z]", " ", text) # return aphapetic rows only
    text = ' '.join(text.split())
    text =  text.lower()
    return text

# Apply after filling NaN with empty string
text_columns = ['Title', 'Plot', 'Director', 'Cast']
for col in text_columns:
    df[col] = df[col].fillna("").swifter.apply(clean_text)
# Out:
# ...
# Pandas Apply:   0%|          | 0/34901 [00:00<?, ?it/s]

# %%
# Create boolean mask for rows where either column contains 'director' or 'cast'
mask = (
    df['Director'].str.contains(r'\b(director|cast)\b', case=False, na=False) |
    df['Cast'].str.contains(r'\b(director|cast)\b', case=False, na=False)
)

df =df[~mask]  # Filter out rows where either 'Director' or 'Cast' contains 'director' or 'cast'

# %%
df = df[df['Genre'].str.lower() != 'unknown'] # Filter out rows where 'Genre' is 'unknown'

# %%
df['Genre'].str.contains(',', na=False).sum() # Count how many rows have multiple genres (comma-separated)
# Out:
# 2905

# %%
# Display the top 15 genres in a bar chart
px.bar(df['Genre'].value_counts().nlargest(15), title='Top 15 Genres')

# %%
def parse_genre_string(genre_string):
    # Convert to string and lower it
    genre_string = str(genre_string).lower()
    # Remove square brackets and extra whitespace
    genre_string = genre_string.strip("[]")
    # Split on slashes and spaces
    genre_list = re.split(r'[/,\s]+', genre_string)
    # Remove empty strings and clean genre names
    genre_list = [re.sub(r'[^a-z]', '', g) for g in genre_list if g]
    return genre_list

# Apply to Genre column
df['Genre'] = df['Genre'].fillna('').swifter.apply(parse_genre_string)
df['Genre']
# Out:
# Pandas Apply:   0%|          | 0/28558 [00:00<?, ?it/s]
# 5           [family, fantasy, adventure]
# 6                              [western]
# 7                               [comedy]
# 10                               [short]
# 11       [short, action, crime, western]
#                       ...
# 34898                      [drama, film]
# 34903                           [comedy]
# 34904                           [comedy]
# 34905                 [romantic, comedy]
# 34906                         [romantic]
# Name: Genre, Length: 28558, dtype: object

# %%
df = df[df['Director'].str.lower() != 'unknown'] # Filter out rows where 'Director' is 'unknown'

# %%
df.shape  # Display the shape of the DataFrame after dropping columns
# Out:
# (28558, 8)

# %%
df.columns # Display the remaining columns in the DataFrame
# Out:
# Index(['Release Year', 'Title', 'Origin/Ethnicity', 'Director', 'Cast',
#        'Genre', 'Wiki Page', 'Plot'],
#       dtype='object')

# %%
df.isna().sum()  # Display the count of missing values in each column
# Out:
# Release Year        0
# Title               0
# Origin/Ethnicity    0
# Director            0
# Cast                0
# Genre               0
# Wiki Page           0
# Plot                0
# dtype: int64

# %%
df.Genre.value_counts().head(10)  # Display the top 10 genres in the DataFrame
# Out:
# Genre
# [drama]           5959
# [comedy]          4386
# [horror]          1166
# [action]          1123
# [thriller]         983
# [romance]          935
# [western]          864
# [crime]            567
# [adventure]        527
# [crime, drama]     497
# Name: count, dtype: int64

# %%
df.drop(columns=['Wiki Page'], inplace=True)  # Drop Wiki Page column

# %% [markdown]
# ## 2- 📊 Variate Analysis

# %%
# Display box plot to visualize outliers in the 'Release Year' column
px.box(df, y='Release Year', title='Outliers in Release Year')

# %%
px.bar(df['Title'].value_counts().nlargest(15), title='Top 50 Titles')

# %%
df = df[df['Title'].notna() & df['Title'].str.strip().ne('')]

# %%
# Display the top 15 directors in a bar chart
px.bar(df['Director'].value_counts().nlargest(20), title='Top 50 Directors')

# %%
df = df[df['Director'].notna() & df['Director'].str.strip().ne('')]

# %%
df.Director.nunique()
# Out:
# 10111

# %%
# Top 10 countries has film production

top_ethnicity = df['Origin/Ethnicity'].value_counts().nlargest(10).reset_index()
top_ethnicity.columns = ['Origin/Ethnicity', 'Count']

px.pie(top_ethnicity, names='Origin/Ethnicity', values='Count', title='Top 10 Movies by Origin/Ethnicity').show()

# %%
text = ' '.join(df['Cast'].dropna().astype(str))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('on')
plt.title("Top Cast Word Cloud")
plt.show()

# %% [markdown]
# 3-**Feature Engineering**

# %%
# Create a new column 'Decade' by flooring the 'Release Year' to the nearest decade
df['Decade'] = (df['Release Year'] // 10) * 10

# %%
df['Cast_Size'] = df['Cast'].swifter.apply(lambda x: len(x.split(',')) if isinstance(x, str) else 0)
# Out:
# Pandas Apply:   0%|          | 0/28050 [00:00<?, ?it/s]

# %%
df['Plot_Length'] = df['Plot'].swifter.apply(lambda x: len(x.split()))
# Out:
# Pandas Apply:   0%|          | 0/28050 [00:00<?, ?it/s]

# %%
px.histogram(df['Plot_Length'], nbins=50, title='Distribution of Plot Lengths (in words)').show()

# %%
def remove_outliers_iqr(df, column, min_limit=None, max_limit=None, iqr_range=1.5, verbose=True):
    """
    Remove outliers based on token length of a text column using IQR or manual limits.
    Always removes rows with length < min_limit or > max_limit if provided.
    """
    df_copy = df.copy()

    # Step 1: Calculate text length
    length_col = f"{column}_Length"
    df_copy[length_col] = df_copy[column].astype(str).apply(lambda x: len(x.split()))

    # Step 2: Compute IQR bounds only if manual bounds not provided
    Q1 = df_copy[length_col].quantile(0.25)
    Q3 = df_copy[length_col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - iqr_range * IQR if min_limit is None else min_limit
    upper_bound = Q3 + iqr_range * IQR if max_limit is None else max_limit

    # Step 3: Apply filtering
    filtered_df = df_copy[
        (df_copy[length_col] >= lower_bound) & (df_copy[length_col] <= upper_bound)
    ].copy()

    if verbose:
        print(f" Original dataset: {len(df)} rows")
        print(f" Cleaned dataset:  {len(filtered_df)} rows")
        print(f" Removed {len(df) - len(filtered_df)} rows outside range {int(lower_bound)}–{int(upper_bound)}")

    return filtered_df

# %%
df = remove_outliers_iqr(df, column='Plot', min_limit=40, max_limit=1200, iqr_range=1.5, verbose=True)
# Out:
#  Original dataset: 28050 rows
#  Cleaned dataset:  26063 rows
#  Removed 1987 rows outside range 40–1200

# %%
df.head(3)  # Display the first 3 rows of the cleaned DataFrame
# Out:
#     Release Year                     Title Origin/Ethnicity  \
# 5           1903       alice in wonderland         American
# 6           1903   the great train robbery         American
# 10          1906  dream of a rarebit fiend         American
#
#                                  Director       Cast  \
# 5                          cecil hepworth  may clark
# 6                          edwin s porter
# 10  wallace mccutcheon and edwin s porter
#
#                            Genre  \
# 5   [family, fantasy, adventure]
# 6                      [western]
# 10                       [short]
#
#                                                  Plot  Decade  Cast_Size  \
# 5   alice follows a large white rabbit down a rabb...    1900          1
# 6   the film opens with two bandits breaking into ...    1900          1
# 10  the rarebit fiend gorges on welsh rarebit at a...    1900          1
#
#     Plot_Length
# 5           231
# 6           240
# 10          158

# %%
px.histogram(df['Plot_Length'], nbins=50, title='Distribution of Plot Lengths (in words)').show()

# %% [markdown]
# <center><span style="font-size:30px; color:White; font-weight:bold;">Pipeline, Modeling & Evaluation</span></center>
#
# #### ✅ Why Use a Pipeline?
#
# Creating a pipeline ensures consistent preprocessing and modeling steps. It prevents data leakage, simplifies cross-validation, and allows for efficient deployment in production environments.
#
# ---
#
# #### 🔧 Pipeline Workflow Covers:
#
# - **Multi-Label Target Handling**
#   - The target column `'Genre'` contains multiple labels per sample.
#   - Used `MultiLabelBinarizer` to convert it into a binary matrix representation.
#
# - **Text Feature Engineering**
#   - Applied `TfidfVectorizer` on the `'Plot'` column to transform raw movie descriptions into numerical embeddings that preserve important narrative signals.
#
# - **Categorical Feature Encoding**
#   - Employed `Onehotencoder` to convert non-numeric columns (like `'Origin/Ethnicity'`) into machine-readable form.
#
# - **Feature Scaling**
#   - Used `RobustScaler(with_centering=False)` to scale numerical features and reduce the influence of outliers.
#
# - **Handling Imbalanced Data**
#   - Addressed imbalance using models with `class_weight='balanced'` rather than synthetic oversampling, which yielded better performance in experimentation.
#
# - **Model Selection for Multi-Label Classification**
#   - Utilized `OneVsRestClassifier` to extend classic classifiers to multi-label problems.
#   - Evaluated multiple models inside the pipeline:
#     - Logistic Regression
#     - Decision Tree
#     - Linear Support Vector
#     - LightGBM
#     - Random Forest
#
# ---
#
# #### 📊 Evaluation Metrics
#
# - **Cross-Validation**
#   - Used 10-fold cross-validation to assess the generalization performance of each model.
#
# - **Metrics Used**
#   - `Hamming Loss`: Measures how many labels are incorrectly predicted.
# ---
#
# > 🔁 The use of `Pipeline` made the modeling process modular, reliable, and suitable for real-world deployment where consistent preprocessing is critical.

# %%
from nltk.tokenize import word_tokenize
numeric_cols   = ['Release Year', 'Decade']
categorical    = ['Origin/Ethnicity']
text_cols      = ['Title', 'Plot', 'Cast', 'Director']
preprocess = ColumnTransformer(
    transformers=[
        #('num', 'passthrough', numeric_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical),
        ('txt_plot',     TfidfVectorizer(max_features=4000, ngram_range=(1,2),
        tokenizer=word_tokenize,stop_words='english'), 'Plot'),
        ('txt_cast',     TfidfVectorizer(max_features=1500), 'Cast'),
        ('txt_director', TfidfVectorizer(max_features=2000), 'Director')
    ],
    remainder='drop'
)

# %%
preprocess.fit(df)  # Fit the preprocessor to the DataFrame
# Out:
# ColumnTransformer(transformers=[('cat', OneHotEncoder(handle_unknown='ignore'),
#                                  ['Origin/Ethnicity']),
#                                 ('txt_plot',
#                                  TfidfVectorizer(max_features=4000,
#                                                  ngram_range=(1, 2),
#                                                  stop_words='english',
#                                                  tokenizer=<function word_tokenize at 0x00000244C48E5D00>),
#                                  'Plot'),
#                                 ('txt_cast', TfidfVectorizer(max_features=1500),
#                                  'Cast'),
#                                 ('txt_director',
#                                  TfidfVectorizer(max_features=2000),
#                                  'Director')])

# %%
x = df.sample(1)  # Sample one random row from the DataFrame
x
# Out:
#       Release Year               Title Origin/Ethnicity        Director  \
# 5616          1952  diplomatic courier         American  henry hathaway
#
#                                            Cast    Genre  \
# 5616  tyrone power patricia neal hildegard knef  [drama]
#
#                                                    Plot  Decade  Cast_Size  \
# 5616  mike kells is assigned by the state department...    1950          1
#
#       Plot_Length
# 5616          271

# %%
# Transform the sample using your preprocessing pipeline
transformed_x = preprocess.transform(x)

# Convert sparse matrix to dense array
dense_array = transformed_x.toarray()

# OPTIONAL: Get feature names if available (depends on pipeline)
try:
    feature_names = preprocess.get_feature_names_out()
except:
    feature_names = [f"feature_{i}" for i in range(dense_array.shape[1])]

# Convert to DataFrame for better readability
transformed_df = pd.DataFrame(dense_array, columns=feature_names)

# Show the result
transformed_df
# Out:
#    cat__Origin/Ethnicity_American  cat__Origin/Ethnicity_Assamese  \
# 0                             1.0                             0.0
#
#    cat__Origin/Ethnicity_Australian  cat__Origin/Ethnicity_Bangladeshi  \
# 0                               0.0                                0.0
#
#    cat__Origin/Ethnicity_Bengali  cat__Origin/Ethnicity_Bollywood  \
# 0                            0.0                              0.0
#
#    cat__Origin/Ethnicity_British  cat__Origin/Ethnicity_Canadian  \
# 0                            0.0                             0.0
#
#    cat__Origin/Ethnicity_Chinese  cat__Origin/Ethnicity_Egyptian  ...  \
# 0                            0.0                             0.0  ...
#
#    txt_director__zhou  txt_director__zieff  txt_director__zinnemann  \
# 0                 0.0                  0.0                      0.0
#
#    txt_director__zito  txt_director__zoltan  txt_director__zombie  \
# ...

# %%
# Split input & Target Features
X = df.drop("Genre" , axis = 1 )
y = df["Genre"]
mlb = MultiLabelBinarizer()
y = mlb.fit_transform(y)  # Transform target variable into binary format

# %%
x.shape , y.shape  # Display the shapes of the input and target features
# Out:
# ((1, 10), (26063, 505))

# %%
# Step 1: Sample from df BEFORE separating X and y
sample_size = 20000
df_sample = df.sample(n=sample_size, random_state=42)

# Step 2: Split features and target from the sample
X_sample = df_sample.drop("Genre", axis=1)
y_sample_raw = df_sample["Genre"]
# Step 3: Transform the target
mlb = MultiLabelBinarizer()
y_sample = mlb.fit_transform(y_sample_raw)

# %%
X_sample.shape, y_sample.shape  # Display the shapes of input features and target variable
# Out:
# ((20000, 9), (20000, 445))

# %%
model = OneVsRestClassifier(
    LogisticRegression(max_iter=1000, class_weight='balanced', C=0.1, penalty='l2')
)


# Create the pipeline
pipeline = Pipeline(
    [
        ("preprocess", preprocess),                # Encoder that combine Ordinal transformed features and Binary transformed features
        #("scaler", RobustScaler()),          # RobustScaler can handle outliers automatically so that's why i schoosed.
        ("model", model)      # Logistic Regression is fast comparing to other models.
    ])

# Fit the pipeline
pipeline.fit(X_sample,y_sample)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Origin/Ethnicity']),
#                                                  ('txt_plot',
#                                                   TfidfVectorizer(max_features=4000,
#                                                                   ngram_range=(1,
#                                                                                2),
#                                                                   stop_words='english',
#                                                                   tokenizer=<function word_tokenize at 0x00000244C48E5D00>),
#                                                   'Plot'),
#                                                  ('txt_cast',
# ...

# %%
# Define your custom scorer
hamming_scorer = make_scorer(hamming_loss, greater_is_better=False)  # minimize loss

# Define scoring metrics
hamming_scorer = make_scorer(hamming_loss, greater_is_better=False)


# Use in cross_validate
results = cross_validate(pipeline, X_sample, y_sample, cv=10, scoring=hamming_scorer, return_train_score=True)

# %%
print(f"Train Hamming : {1+results['train_score'].mean()}") # Evaluate the model on the sample data
print(f"Test Hamming : {1+results['test_score'].mean()}") # Evaluate the model on the sample data
# Out:
# Train Hamming : 0.9946131086142322
# Test Hamming : 0.993343595505618

# %%
# Create a list of models
models = [
    
    #("lr",  OneVsRestClassifier(LogisticRegression(max_iter=1000))),
    ("dtr", OneVsRestClassifier(DecisionTreeClassifier())),
    ("svc", OneVsRestClassifier(LinearSVC())),
    ("lgbm", OneVsRestClassifier(LGBMClassifier())),
    ("rfr", OneVsRestClassifier(RandomForestClassifier())),
    ]

# Empty lists for results
name = []
train_accuracy = []
test_accuracy = []
timetaken = []

# Loop through models
for model_name, model in models:
    # Start time
    start_time = perf_counter()
    
    # Create a pipeline with SMOTE, Encoder, Scaler, and the model
    pipeline = ImbPipeline([
        ("preprocess", preprocess),
        #("SMOTE", SMOTE(random_state=42)),
        ("Scaler", RobustScaler(with_centering=False)),
        ("model", model)
    ])
    
    # Fit and evaluate the pipeline using cross-validation
    results = cross_validate(pipeline, X_sample, y_sample, cv=10, scoring= hamming_scorer, return_train_score=True, n_jobs=-1
    )
    
    # Add results to lists
    name.append(model_name)
    train_accuracy.append(results["train_score"].mean())
    test_accuracy.append(results["test_score"].mean())
    
    # End time
    end_time = perf_counter()
    timetaken.append(end_time - start_time)

# Create a DataFrame with the results
data = {'Algorithm': name, 'Train_Accuracy': train_accuracy, 'Test_Accuracy': test_accuracy, 'TimeTaken': timetaken}
result = pd.DataFrame(data)

# Print the DataFrame
result.sort_values(by='Test_Accuracy', ascending=False)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  4.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  2.4min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed: 59.1min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  8.0min finished
#   Algorithm  Train_Accuracy  Test_Accuracy    TimeTaken
# 3       rfr        0.999993       0.994142   479.091958
# 1       svc        0.999705       0.993880   146.901466
# 0       dtr        0.999999       0.991157   295.925677
# 2      lgbm        0.998353       0.990411  3548.520987

# %%
# split data into 80% as train data and 20% for testing.
X_train,X_test,y_train,y_test = train_test_split(X_sample,y_sample,test_size = 0.2,random_state = 42)
print({"X_train":X_train.shape,"X_test":X_test.shape})
print({"y_train":y_train.shape,"y_test":y_test.shape})
# Out:
# {'X_train': (16000, 9), 'X_test': (4000, 9)}
# {'y_train': (16000, 445), 'y_test': (4000, 445)}

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Origin/Ethnicity']),
#                                                  ('txt_plot',
#                                                   TfidfVectorizer(max_features=4000,
#                                                                   ngram_range=(1,
#                                                                                2),
#                                                                   stop_words='english',
#                                                                   tokenizer=<function word_tokenize at 0x00000244C48E5D00>),
#                                                   'Plot'),
#                                                  ('txt_cast',
# ...

# %%
y_pred = pipeline.predict(X_test)

# %%
1 - hamming_loss(y_test, y_pred)
# Out:
# 0.9937073033707865

# %%
import random

# %%
random.seed(100)
random_index = random.randint(0,len(df))
random_index

random_index = random.randint(0, len(df))
print("Random index:", random_index)
# Out:
# Random index: 15057

# %%
df["Genre"].loc[10000]
# Out:
# ['drama']

# %%
New_Record = df.drop("Genre", axis=1).loc[random_index].to_numpy().reshape(1, -1) 

reshaped_record = pd.DataFrame(data=New_Record, columns=df.drop("Genre", axis=1).columns)

reshaped_record
# Out:
#   Release Year         Title Origin/Ethnicity            Director  \
# 0         2006  rocky balboa         American  sylvester stallone
#
#                                                 Cast  \
# 0  sylvester stallone burt young geraldine hughes...
#
#                                                 Plot Decade Cast_Size  \
# 0  rocky balboa now in his late fifties and retir...   2000         1
#
#   Plot_Length
# 0         651

# %%
mlb.inverse_transform(pipeline.predict(reshaped_record))[0] # Inverse transform to get original genre labels
# Out:
# ('drama',)

# %% [markdown]
# <center><span style="font-size:30px; color:White; font-weight:bold;">Non-Spoiler Summaries for Movie Plots</span></center>
#
# #### 🧠 Goal:
# To generate brief, non-spoiler summaries of movie plots that avoid revealing major twists or endings, making them safe for readers who haven't watched the films.
#
# ---
#
# #### 🔍 Approach:
#
# - **LLM Used:**
#   Leveraged the `google/flan-t5-xl` transformer model via Hugging Face's `pipeline("text2text-generation/summarization")` to produce high-quality summaries.
#
# - **Custom Prompting:**
#   Each movie plot was summarized using a tailored prompt to instruct the model *not* to reveal spoilers:
#   *"Summarize the following movie plot without revealing major twists or the ending:"*
#
# - **Sample Size:**
#   Applied the summarization to a small random sample (e.g., 10 rows) from the `Plot` column for demonstration and evaluation.
#
# ---
#
# #### 🧪 Evaluation:
#
# - **Metric Used:**
#   BERTScore (F1) was computed to evaluate the semantic similarity between the generated summaries and the original movie plots.
#
# - **Observations:**
#   - BERTScore assesses contextual similarity rather than exact word overlap, making it more suitable for abstractive summaries.
#
#   -  The average BERTScore F1 value indicated strong semantic preservation in the summaries, despite omitting spoilers and compressing details.
#
#   -   This validates that the summarizer retained key plot essence while avoiding sensitive content.
# ---
#
# > 🚀 This step adds explainability and usability to the dataset, especially for user-facing applications like movie recommendation systems or content browsing tools.

# %%
from transformers import pipeline

# Initialize the instruction-following model
summarizer = pipeline("text2text-generation", model="google/flan-t5-xl")

# Sample non-empty plots with titles
sample_df = df[df['Plot'].str.len() > 700][['Title', 'Plot']].sample(n=3, random_state=42).reset_index(drop=True)

# Define the instruction-based summarizer
def summarize_non_spoiler(plot_text):
    prompt = (
    "Summarize the following movie plot without revealing major twists or the ending:\n\n" + plot_text[:3000]
)
    
    # Print the prompt for debugging
    print("---- Prompt Sent to Model ----")
    print(prompt[:500])
    print("------------------------------\n")
    
    try:
        response = summarizer(prompt, max_length=100, min_length=30, do_sample=False)
        return response[0]['generated_text'] if response else "[No summary returned]"
    except Exception as e:
        return f"[Error: {e}]"

# Apply summarization
results = []
for idx, row in sample_df.iterrows():
    summary = summarize_non_spoiler(row['Plot'])
    results.append({
        'Title': row['Title'],
        'Original Plot': row['Plot'],
        'Non-Spoiler Summary': summary
    })

# Create DataFrame with titles as index
summary_df = pd.DataFrame(results).set_index("Title")

summary_df
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cpu
# ---- Prompt Sent to Model ----
# Summarize the following movie plot without revealing major twists or the ending:
#
# the plot exists on three levels first there is the frame story where in the south of england in the s a struggling theatrical troupe is performing a musical about romantic intrigues at a finishing school for young women in the south of france as well as weathering ongoing backstage dramas and audiences that are smaller in number than the cast two extra stressors arrive a famous hollywood film producer turns up to s
# ------------------------------
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
summary_df.to_excel("non_spoiler_summaries.xlsx", index=False)  # Save summaries to Excel file

# %%
from evaluate import load
import numpy as np

# 1. Load the metric
bertscore = load("bertscore")

# 2. Prepare the predicted summaries and references
predictions = summary_df["Non-Spoiler Summary"].tolist()
references = summary_df["Original Plot"].tolist()  # or gold-standard summaries if available

# 3. Compute BERTScore
bertscore_result = bertscore.compute(predictions=predictions, references=references, lang="en")

# 4. Display result
print(f"Average BERTScore F1: {np.mean(bertscore_result['f1']):.4f}")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Average BERTScore F1: 0.9213

# %% [markdown]
# <center><span style="font-size:30px; color:White; font-weight:bold;">Vector DB & RAG</span></center>
#
# #### 🧠 Goal:
# To implement a semantic search and retrieval-augmented generation (RAG) system that enhances information access by returning contextually relevant movie plots and answers to user queries.
#
# ---
#
# #### 📦 Components:
#
# - **Sentence Embedding Model:**
#   Used `sentence-transformers/all-MiniLM-L6-v2` to convert movie plots into dense vector embeddings for semantic understanding.
#
# - **Vector Database:**
#   Built using **FAISS (Facebook AI Similarity Search)** to store and index plot embeddings efficiently and support fast nearest-neighbor retrieval.
#
# ---
#
# #### 🔍 Semantic Search Functionality:
#
# - Encoded all plot texts into normalized vectors.
# - Used cosine similarity via `IndexFlatIP` in FAISS to retrieve the top `k` most relevant plots for a given query.
# - Created a `search_movies(query)` function to return movie titles, plots, and relevance scores.
#
# ---
#
# #### 🧩 Retrieval-Augmented Generation (RAG):
#
# - Implemented a lightweight RAG system using `google/flan-t5-base`.
# - For any user question, the system:
#   1. Retrieves top-matching plots from the FAISS vector DB.
#   2. Concatenates them into a prompt passed to the LLM.
#   3. Generates a contextual answer based on retrieved knowledge.
#
# ---
#
# #### ⚙️ Sample Use Case:
#
# - **Query:** *"what is the shawshank redemption movie about"*
# - **System Output:**
#   - **RAG Answer:** Synthesized based on retrieved movie plots.
#   - **Retrieved Context:** Titles and summaries of the top related films.
#
# ---
#
# > 💡 This setup makes the system capable of intelligent movie recommendation, plot-based search, and natural-language Q&A — ideal for enhancing user interactivity in movie exploration tools.

# %%
 # Build enriched text + FAISS index  (re-run only if df changes)
#assert {'Title', 'Plot'}.issubset(df.columns), "df needs Title & Plot columns"

# Create richer document text for better semantic retrieval
def make_rag_text(row):
    # If Genre is list -> join; else cast to str
    genre_str = ", ".join(row['Genre']) if isinstance(row['Genre'], list) else str(row.get('Genre', ''))
    return f"Title: {row['Title']}\nGenre: {genre_str}\nPlot: {row['Plot']}"

df['RAG_Text'] = df.swifter.apply(make_rag_text, axis=1)
# Out:
# Pandas Apply:   0%|          | 0/26063 [00:00<?, ?it/s]

# %%
df.head(3)  # Display the first 3 rows of the DataFrame with RAG_Text
# Out:
#     Release Year                     Title Origin/Ethnicity  \
# 5           1903       alice in wonderland         American
# 6           1903   the great train robbery         American
# 10          1906  dream of a rarebit fiend         American
#
#                                  Director       Cast  \
# 5                          cecil hepworth  may clark
# 6                          edwin s porter
# 10  wallace mccutcheon and edwin s porter
#
#                            Genre  \
# 5   [family, fantasy, adventure]
# 6                      [western]
# 10                       [short]
#
#                                                  Plot  Decade  Cast_Size  \
# 5   alice follows a large white rabbit down a rabb...    1900          1
# 6   the film opens with two bandits breaking into ...    1900          1
# 10  the rarebit fiend gorges on welsh rarebit at a...    1900          1
#
#     Plot_Length                                           RAG_Text
# ...

# %%
# -- Encode
encoder   = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

embeddings = encoder.encode(
    df['RAG_Text'].tolist(),
    show_progress_bar=True,
    convert_to_numpy=True,
    normalize_embeddings=True 
)


# -- FAISS cosine index
dim   = embeddings.shape[1]
index = faiss.IndexFlatIP(dim)
index.add(embeddings)

print(f"✓ FAISS vector DB built ({index.ntotal} docs, dim={dim})")
# Out:
# Batches:   0%|          | 0/815 [00:00<?, ?it/s]
# ✓ FAISS vector DB built (26063 docs, dim=384)

# %%
def search_movies(query: str, top_k: int = 5) -> pd.DataFrame:
    q_vec          = encoder.encode([query], normalize_embeddings=True)
    scores, idx    = index.search(q_vec, top_k)
    hits           = df.iloc[idx[0]].copy()
    hits['Score']  = scores[0]
    return hits[['Title', 'Plot', 'Score']].reset_index(drop=True)

# %%
if __name__ == "__main__":
    sample_query = "what is the shawshank redemption movie about"
    results = search_movies(sample_query, top_k=3)

    print("🔍  Query:", sample_query)
    print(results[["Title", "Score"]])
    # If you want full plots too:
    # display(results[["Title", "Score", "Plot"]])
# Out:
# 🔍  Query: what is the shawshank redemption movie about
#                       Title     Score
# 0  the shawshank redemption  0.621743
# 1                 karmayogi  0.433292
# 2             the challenge  0.428291

# %%
gen_name   = "google/flan-t5-base"          # small, fast, open-source
tokenizer  = AutoTokenizer.from_pretrained(gen_name) # tokenizer for text2text generation
generator  = AutoModelForSeq2SeqLM.from_pretrained(gen_name) # load the model for text2text generation
gen_pipe   = pipeline("text2text-generation", model=generator, tokenizer=tokenizer) # text2text generation pipeline
# Out:
# Device set to use cpu

# %%
def rag_qa(question: str, top_k: int = 5, max_new_tokens: int = 128):
    retrieved = search_movies(question, top_k=top_k)
    
    # Assemble context with title & plot for each hit
    context = "\n\n---\n\n".join(
        f"Title: {row.Title}\nPlot: {row.Plot}" for _, row in retrieved.iterrows()
    )

    prompt = (
        "Using the information in the movie plots below, answer the question "
        "WITHOUT revealing major spoilers.\n\n"
        f"{context}\n\n"
        f"Question: {question}\nAnswer:"
    )

    answer = gen_pipe(prompt, do_sample=False, max_new_tokens=max_new_tokens)[0]['generated_text']
    return answer.strip(), retrieved[['Title', 'Score']]

# 🔎 Demo
user_q = "what is the shawshank redemption movie about"
ans, ctx = rag_qa(user_q, top_k=5)

print("Question:", user_q)
print("\nAnswer:", ans)
print("\nTop-k retrieved:")
display(ctx)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (2245 > 512). Running this sequence through the model will result in indexing errors
# Question: what is the shawshank redemption movie about
#
# Answer: in portland maine banker andy dufresne is convicted of murdering his wife and her lover and sentenced to two consecutive life sentences at the shawshank state penitentiary he is befriended by contraband smuggler ellis red redding an inmate serving a life sentence at the shawshank state penitentiary he is befriended by contraband smuggler ellis red redding an inmate serving a life sentence at the shawshank state pen
#
# Top-k retrieved:
#                       Title     Score
# 0  the shawshank redemption  0.621743
# 1                 karmayogi  0.433292
# 2             the challenge  0.428291
# 3                   payback  0.427777
# 4           krishna cottage  0.421894

# %% [markdown]
# <center><span style="font-size:30px; color:White; font-weight:bold;">Q&A Deployment Using Gradio</span></center>
#
# #### 🎯 Goal:
# Deploy an interactive interface that allows users to ask natural language questions about movies and receive intelligent, context-aware answers powered by RAG (Retrieval-Augmented Generation).
#
# ---
#
# #### 🚀 Tools Used:
#
# - **Gradio:**
#   A fast and user-friendly library to create web-based UIs for ML models.
#
# - **Vector DB (FAISS):**
#   Performs semantic retrieval of movie plots relevant to the user’s question.
#
# - **Language Model:**
#   `google/flan-t5-base` generates concise and informative answers based on the retrieved context.
#
# ---
#
# #### 🧩 How It Works:
#
# 1. **User Inputs a Question** – e.g., *“what is the shawshank redemption movie about?”*
# 2. **Plot Retrieval** – Top 3 most relevant movie plots are fetched from the FAISS vector database using semantic similarity.
# 3. **Answer Generation** – The retrieved content is passed into the LLM along with the question to generate a grounded response.
# 4. **Answer Display** – Gradio interface presents both the generated answer and a preview of retrieved movie titles/plots.
#
# ---
#
# #### 🖥 Interface Features:
#
# - **Text Input Box** for user questions.
# - **Answer Section** showing generated output.
# - **Context Preview** listing relevant movie titles retrieved from the database.
# - Fast response time and intuitive UX, all run locally or hosted online via Gradio sharing.
#
# ---
#
# > ✅ This deployment enables end users to interact with your movie intelligence system in real-time — transforming raw movie data into actionable, conversational insights.

# %%
import gradio as gr # Gradio for web interface

def rag_gradio(query): 

    """
    Gradio interface function for RAG Q&A.
    Takes a user query, retrieves relevant movie plots, and generates an answer.
    Args:
        query (str): User's question about a movie. 
    Returns:
        tuple: A tuple containing:
            - movie_titles (str): Formatted string of top-k movie titles and their scores.
            - answer (str): Generated answer to the user's query.
    """
    
    answer, hits = rag_qa(query)
    movie_titles = "\n".join(f"- {row['Title']} ({row['Score']:.2f})" for _, row in hits.iterrows()) # Format titles with scores
    return movie_titles, answer # Return titles and answer

gr.Interface(
    fn=rag_gradio, # Function to call for RAG Q&A
    inputs=gr.Textbox(label="Ask about a movie"),# User input textbox for movie questions
    outputs=[
        gr.Textbox(label="Top Matches"), # Output textbox for top-k movie titles and scores
        gr.Textbox(label="Answer") # Output textbox for the generated answer
    ],
    title="🎬 RAG Movie Q&A",
    description="Ask about movie plots. Powered by FAISS + Flan-T5.",
).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "c:\Users\145568\MLenv\Lib\site-packages\gradio\queueing.py", line 626, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\145568\MLenv\Lib\site-packages\gradio\route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\145568\MLenv\Lib\site-packages\gradio\blocks.py", line 2220, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# <center><span style="font-size:30px; color:White; font-weight:bold;">Conclusion</span></center>
#
#
# ## In this project, I performed data cleaning, feature extraction, and exploratory data analysis on movie metadata, focusing on columns like Cast_Size, Director, and Genres. I applied custom functions to handle missing values, normalize text, and extract relevant fields from JSON-like structures. I visualized distributions and identified features with low variance or missing data. These steps prepared the dataset for further modeling and ensured its quality and consistency.
